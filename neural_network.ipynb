# %% [markdown]
# <a href="https://colab.research.google.com/github/kopildas/Machin-learning-lab-tasks/blob/main/neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ML lab task 15.5.23 **

# %%
# import tensorflow.keras as keras
import tensorflow as tf
import numpy as np
import pandas as pd

# %% [markdown]
# data load

# %%
path = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/feature_class_data.csv')
path
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
X = path.drop(columns=['1'])
y = path['1']
X
# Out:
#       6  148  72  35    0  33.6  0.627  50
# 0     1   85  66  29    0  26.6  0.351  31
# 1     8  183  64   0    0  23.3  0.672  32
# 2     1   89  66  23   94  28.1  0.167  21
# 3     0  137  40  35  168  43.1  2.288  33
# 4     5  116  74   0    0  25.6  0.201  30
# ..   ..  ...  ..  ..  ...   ...    ...  ..
# 762  10  101  76  48  180  32.9  0.171  63
# 763   2  122  70  27    0  36.8  0.340  27
# 764   5  121  72  23  112  26.2  0.245  30
# 765   1  126  60   0    0  30.1  0.349  47
# 766   1   93  70  31    0  30.4  0.315  23
#
# [767 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# The training set contains 80% of the data
print(len(X_train))
# 1000

# The test set contains 20% of the data
print(len(X_test))
# 250
# Out:
# 613
# 154

# %%
#Model Architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

model = Sequential()
model.add(Flatten())
model.add(Dense(32, activation=tf.nn.relu))
model.add(Dense(64, activation=tf.nn.relu))
model.add(Dense(128, activation=tf.nn.relu))
#model.add(Dense(256, activation=tf.nn.relu))
model.add(Dense(2, activation=tf.nn.softmax))
          
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=1000)
# Out:
# Epoch 1/1000
# 20/20 [==============================] - 1s 2ms/step - loss: 4.0954 - accuracy: 0.5889
# Epoch 2/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5212 - accuracy: 0.6101
# Epoch 3/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8260 - accuracy: 0.6639
# Epoch 4/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6740 - accuracy: 0.6900
# Epoch 5/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8291 - accuracy: 0.6427
# Epoch 6/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6872 - accuracy: 0.6949
# Epoch 7/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8863 - accuracy: 0.6460
# Epoch 8/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6323 - accuracy: 0.7096
# Epoch 9/1000
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0731 - accuracy: 0.6215
# Epoch 10/1000
# ...

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(test_loss)
print(test_acc)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 2.9459 - accuracy: 0.6364
# 2.9459335803985596
# 0.6363636255264282
